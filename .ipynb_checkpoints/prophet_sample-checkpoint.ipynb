# %% [markdown]
# # Docker&jupyterの起動
# ###  jupyter入ってない方用です
# ```docker run -it --rm -p 8888:8888 jupyter/datascience-notebook
# http://localhost:8888/?token=xxxxxxxxxxxxxxxxxxxxx
# ```

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # データのダウンロード
# ### データセットはPandas経由で取得したNASDAQのFacebookのデータです

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.5.0-py2.py3-none-any.whl (74kB)
#     100% |████████████████████████████████| 81kB 622kB/s
# Collecting requests-file (from pandas_datareader)
#   Downloading requests-file-1.4.2.tar.gz
# Requirement already satisfied: pandas>=0.17.0 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pandas_datareader)
# Collecting requests-ftp (from pandas_datareader)
#   Downloading requests-ftp-0.3.1.tar.gz
# Requirement already satisfied: requests>=2.3.0 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pandas_datareader)
# Requirement already satisfied: six in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from requests-file->pandas_datareader)
# Requirement already satisfied: python-dateutil>=2 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pandas>=0.17.0->pandas_datareader)
# Requirement already satisfied: pytz>=2011k in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pandas>=0.17.0->pandas_datareader)
# Requirement already satisfied: numpy>=1.7.0 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pandas>=0.17.0->pandas_datareader)
# Building wheels for collected packages: requests-file, requests-ftp
# done
#   Stored in directory: /Users/yukitanimoto/Library/Caches/pip/wheels/3e/34/3a/c2e634ca7b545510c1b3b7d94dea084e5fdb5f33558f3c3a81
# done
#   Stored in directory: /Users/yukitanimoto/Library/Caches/pip/wheels/76/fb/0d/1026eb562c34a4982dc9d39c9c582a734eefe7f0455f711deb
# Successfully built requests-file requests-ftp
# Installing collected packages: requests-file, requests-ftp, pandas-datareader
# Successfully installed pandas-datareader-0.5.0 requests-file-1.4.2 requests-ftp-0.3.1

# %%
from pandas_datareader.data import DataReader
from datetime import datetime

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)
fb = DataReader('FB', 'yahoo', start, end)

fb.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-09-27  127.610001  129.009995  127.430000  128.690002  128.690002
# 2016-09-28  129.210007  129.470001  128.399994  129.229996  129.229996
# 2016-09-29  129.179993  129.289993  127.550003  128.089996  128.089996
# 2016-09-30  128.029999  128.589996  127.449997  128.270004  128.270004
# 2016-10-03  128.380005  129.089996  127.800003  128.770004  128.770004
#
#               Volume
# Date
# 2016-09-27  15637100
# 2016-09-28  12047600
# 2016-09-29  14532200
# 2016-09-30  18402900
# 2016-10-03  13156900

# %%
from matplotlib.finance import candlestick2_ohlc

# ローソクだけをプロット
fig = plt.figure(figsize=(18, 9))
ax = plt.subplot(1, 1, 1)

# candlestick2を使って描画
candlestick2_ohlc(ax, fb["Open"], fb["High"], fb["Low"], fb["Close"], width=0.9, colorup="b", colordown="r")

# 軸メモリやラベルを整える
ax.set_ylabel("Price")
plt.show()

# %% [markdown]
# # Prophetによる時系列予測

# %%
# !pip install pystan
# !pip install fbprophet
# Out:
# Collecting pystan
#   Downloading pystan-2.16.0.0-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (34.6MB)
#     100% |████████████████████████████████| 34.6MB 17kB/s
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pystan)
# Requirement already satisfied: numpy>=1.7 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pystan)
# Installing collected packages: pystan
# Successfully installed pystan-2.16.0.0
# Collecting fbprophet
#   Downloading fbprophet-0.2.tar.gz
# Requirement already satisfied: matplotlib in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from fbprophet)
# Collecting pandas>=0.18.1 (from fbprophet)
#   Downloading pandas-0.20.3-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (14.7MB)
#     100% |████████████████████████████████| 14.7MB 28kB/s
# Requirement already satisfied: pystan>=2.14 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from fbprophet)
# Requirement already satisfied: numpy>=1.6 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: python-dateutil in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pytz in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: cycler in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pyparsing!=2.0.4,>=1.5.6 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from pystan>=2.14->fbprophet)
# Requirement already satisfied: six>=1.5 in /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages (from python-dateutil->matplotlib->fbprophet)
# Building wheels for collected packages: fbprophet
# done
#   Stored in directory: /Users/yukitanimoto/Library/Caches/pip/wheels/ae/90/23/ef753de5757d77bb1b5a6bb9846c1d36689355bdb5ddf67862
# Successfully built fbprophet
# Installing collected packages: pandas, fbprophet
#   Found existing installation: pandas 0.18.0
#     Uninstalling pandas-0.18.0:
#       Successfully uninstalled pandas-0.18.0
# Successfully installed fbprophet-0.2 pandas-0.20.3

# %%
from fbprophet import Prophet

# %%
#read dataset
df = fb
df['y'] = df['Close']
df.reset_index(level='Date', inplace=True)
df = df.rename(columns = {'Date':'ds'})

# %%
#split dataset for train-test
df = df.sort_values(by='ds')
df_test = df.tail(30)
df_train = df.head(df.ds.count() -30)

# %%
#prediction
m = Prophet()
m.fit(df_train)

# %%
future = m.make_future_dataframe(periods=30)

# %%
forecast = m.predict(future)
verification = pd.merge(df_test, forecast[['ds', 'yhat']].tail(30), on= 'ds')

verification['diff'] = abs(1-verification.yhat/verification.y)

# %%
m.plot(forecast)
plt.show()

# %%
# トレンドと曜日成分の寄与度
m.plot_components(forecast)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-a75e5e51f930> in <module>()
#       1 # トレンドと曜日成分の寄与度
# ----> 2 m.plot_components(forecast)
#       3 plt.show()
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/fbprophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start)
#    1311             elif plot == 'weekly':
#    1312                 self.plot_weekly(
# -> 1313                     ax=ax, uncertainty=uncertainty, weekly_start=weekly_start)
#    1314             elif plot == 'yearly':
#    1315                 self.plot_yearly(
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/fbprophet/forecaster.py in plot_weekly(self, ax, uncertainty, weekly_start)
#    1403         df_w = self.seasonality_plot_df(days)
#    1404         seas = self.predict_seasonal_components(df_w)
# -> 1405         days = days.weekday_name
#    1406         artists += ax.plot(list(range(len(days))), seas['weekly'], ls='-',
#    1407                            c='#0072B2')
#
# AttributeError: 'DatetimeIndex' object has no attribute 'weekday_name'

# %%
# 直近30日を予測してみた
print('difference')
print(verification['diff'])

verification.plot(x= 'ds', y= ['y','yhat'], style='.')
verification.plot(x= 'ds', y= 'diff', kind='bar')
plt.show()
# Out:
# difference
# 0     0.016713
# 1     0.002962
# 2     0.000156
# 3     0.002012
# 4     0.008337
# 5     0.001241
# 6     0.005997
# 7     0.014778
# 8     0.013270
# 9     0.009030
# 10    0.000458
# 11    0.010946
# 12    0.011048
# 13    0.001108
# 14    0.005265
# 15    0.010280
# 16    0.002990
# 17    0.007880
# 18    0.004100
# 19    0.003030
# 20    0.010594
# Name: diff, dtype: float64
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-c9ca7f2b6239> in <module>()
#       3 print(verification['diff'])
#       4
# ----> 5 verification.plot(x= 'ds', y= ['y','yhat'], style='.')
#       6 verification.plot(x= 'ds', y= 'diff', kind='bar')
#       7 plt.show()
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in _make_plot(self)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in _is_ts_plot(self)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in _use_dynamic_x(self)
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/tseries/plotting.py in <module>()
#       1 # flake8: noqa
#       2
# ----> 3 from pandas.plotting._timeseries import tsplot
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/plotting/__init__.py in <module>()
#      11     pass
#      12
# ---> 13 from pandas.plotting._misc import (scatter_matrix, radviz,
#      14                                    andrews_curves, bootstrap_plot,
#      15                                    parallel_coordinates, lag_plot,
#
# /Users/yukitanimoto/anaconda3/lib/python3.5/site-packages/pandas/plotting/_misc.py in <module>()
#       6
#       7 from pandas.util._decorators import deprecate_kwarg
# ----> 8 from pandas.core.dtypes.missing import notnull
#       9 from pandas.compat import range, lrange, lmap, zip
#      10 from pandas.io.formats.printing import pprint_thing
#
# ImportError: No module named 'pandas.core.dtypes.missing'; 'pandas.core.dtypes' is not a package
